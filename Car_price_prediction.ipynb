# %% [markdown]
# <a href="https://colab.research.google.com/github/harish-03-11/Car-price-prediction_Harish/blob/main/Car_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/sample_data/car data.csv")

# %%
df.head(3)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0

# %%
df.info(

)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.replace({"Manual": 0,"Automatic": 1}, inplace = True)

# %%
df1 = df

# %%
df1.sample(3)
# Out:
#              Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 140     Honda CBR 150  2013            0.6           1.20       32000
# 290             amaze  2014            4.5           6.40       19000
# 142  Yamaha FZ  v 2.0  2015            0.6           0.84       29000
#
#     Fuel_Type Seller_Type  Transmission  Owner
# 140    Petrol  Individual             0      0
# 290    Petrol      Dealer             0      0
# 142    Petrol  Individual             0      0

# %%
df1.replace({'True':1, 'False':0}, inplace = True)

# %%
df1.sample(3)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 26     swift  2013           4.15           5.87       55138    Petrol
# 271     city  2009           3.00          10.00       69562    Petrol
# 296     city  2016           9.50          11.60       33988    Diesel
#
#     Seller_Type  Transmission  Owner
# 26       Dealer             0      0
# 271      Dealer             0      0
# 296      Dealer             0      0

# %%
df1.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df1.replace({'True':1, 'False':0}, inplace = True)

# %%
df.Seller_Type.value_counts()
# Out:
# Seller_Type
# Dealer        195
# Individual    106
# Name: count, dtype: int64

# %%
df1.replace({'Seller_Type': {'Dealer':0,'Individual':1}},inplace=True)

# %%
df1.sample(3)
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 56                 etios cross  2015            4.5           7.27
# 109  Royal Enfield Classic 350  2017            1.2           1.47
# 125  Royal Enfield Classic 500  2009            0.9           1.75
#
#      Kms_Driven Fuel_Type  Seller_Type  Transmission  Owner
# 56        40534    Petrol            0             0      0
# 109       11000    Petrol            1             0      0
# 125       40000    Petrol            1             0      0

# %%
df1.Fuel_Type.value_counts()
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %%
df1.replace({'Fuel_Type': {'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)

# %%
df1.sample(2)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 73    etios liva  2011           2.65           5.71       43000          0
# 178  TVS Jupyter  2014           0.35           0.52       19000          0
#
#      Seller_Type  Transmission  Owner
# 73             0             0      0
# 178            1             1      0

# %%
df1['Selling_Price'] = df1['Selling_Price'].apply(lambda x : x*100000,)
df1['Present_Price'] = df1['Present_Price'].apply(lambda y : y*100000,)

# %%
df1.sample(10)
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 220                        eon  2017       350000.0       443000.0
# 22                         sx4  2011       440000.0       801000.0
# 116  Royal Enfield Classic 350  2013       110000.0       147000.0
# 269                       city  2015       670000.0      1000000.0
# 36                       dzire  2015       465000.0       720000.0
# 141   Bajaj Avenger 150 street  2016        60000.0        80000.0
# 110                  KTM RC200  2016       120000.0       178000.0
# 257                       city  2015       850000.0      1360000.0
# 180     Hero Honda Passion Pro  2012        30000.0        51000.0
# 167         TVS Apache RTR 160  2014        42000.0        81000.0
#
#      Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner
# 220       38488          0            0             0      0
# 22        50000          0            0             1      0
# ...

# %%
X = df1.drop(['Car_Name','Selling_Price'],axis=1)
y = df1['Selling_Price']

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso

# %%
X_train, X_test , y_train, y_test = train_test_split(X,y, test_size = 0.1, random_state = 42)

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train,)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_train)

# %%
from sklearn import metrics

# %%
error = metrics.r2_score(y_train,y_pred)

# %%
print(error)
# Out:
# 0.8806173715719134

# %%
plt.scattery_train,y_pred)

# %%
plt.scatter(y_train,y_pred)

# %%
test_pred = model.predict(X_test)

# %%
test_error = metrics.r2_score(test_pred , y_test)

# %%
print(test_error)
# Out:
# 0.7593427825981324

# %%
lass_model = Lasso()

# %%
lass_model.fit(X_train,y_train)
# Out:
# Lasso()

# %%
lasso_trian_pred = lass_model.predict(X_train)

# %%
lass_error = metrics.r2_score(lasso_trian_pred,y_train)

# %%
print(lass_error)
# Out:
# 0.8644323978838149

# %%
plt.scatter(lasso_trian_pred,y_train)
